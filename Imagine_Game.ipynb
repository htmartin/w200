# %%
# Write a Python program to clone or copy a list.

# %%
nouns = ['Animal', 'Apple', 'Balloon', 'Banana',  'Bed', 'Breakfast', 'Candle', 'Car', 'Caravan', 'Carpet', 'Cartoon', 'Crayon', 'Diamond', 'Dog',  'Dress', 'Egg', 'Eggplant', 'Elephant', 'Eye', 'Fish', 'Flag', 'Flower', 'Football', 'Forest', 'Fountain']

# %%
colors = ['green', 'black', 'blue', 'yellow', 'brown', 'cerulean','purple', 'red']

# %%
for n in nouns:
    for c in colors:
        print(c,n)
        
#Imagine Game
# next add these to a list
# rand to select one
# Out:
# green Actor
# black Actor
# blue Actor
# yellow Actor
# brown Actor
# cerulean Actor
# purple Actor
# red Actor
# green Advertisement
# black Advertisement
# blue Advertisement
# yellow Advertisement
# brown Advertisement
# cerulean Advertisement
# purple Advertisement
# red Advertisement
# green Afternoon
# black Afternoon
# blue Afternoon
# yellow Afternoon
# brown Afternoon
# cerulean Afternoon
# purple Afternoon
# red Afternoon
# green Airport
# black Airport
# blue Airport
# yellow Airport
# brown Airport
# cerulean Airport
# purple Airport
# red Airport
# green Ambulance
# black Ambulance
# blue Ambulance
# yellow Ambulance
# brown Ambulance
# cerulean Ambulance
# purple Ambulance
# red Ambulance
# green Animal
# black Animal
# blue Animal
# yellow Animal
# brown Animal
# cerulean Animal
# purple Animal
# red Animal
# green Answer
# black Answer
# blue Answer
# yellow Answer
# brown Answer
# cerulean Answer
# purple Answer
# red Answer
# green Apple
# black Apple
# blue Apple
# ...

# %%
# replace('\t', 'any other string that you want to replace the tab with') .
